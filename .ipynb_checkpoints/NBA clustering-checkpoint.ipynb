# %% [markdown]
# # NBA Clustering based on advanced stats

# %% [markdown]
# ## Importing stats:

# %%
shooting_names = ['Player', 'Team', 'AGE', 'FGM LESS THAN 5FT.', 'FGA LESS THAN 5FT.',\
       'FG% LESS THAN 5FT.', 'FGM 5-9 FT.', 'FGA 5-9 FT.', 'FG% 5-9 FT.',\
       'FGM 10-14 FT.', 'FGA 10-14 FT.', 'FG% 10-14 FT.', 'FGM 15-19 FT.',\
       'FGA 15-19 FT.', 'FG% 15-19 FT.', 'FGM 20-24 FT.', 'FGA 20-24 FT.',\
       'FG% 20-24 FT.', 'FGM 25-29 FT.', 'FGA 25-29 FT.', 'FG% 25-29 FT.']
passing_names = ['Player', 'Team', 'PASSES MADE', 'PASSES RECEIVED', 'SECONDARY AST',\
       'POTENTIAL AST', 'AST ADJ', 'AST to PASS% ADJ']
drives_names = ['PLAYER', 'TEAM', 'DRIVES']
touches_names = ['PLAYER', 'TEAM', 'TOUCHES', 'FRONT CT TOUCHES', 'TIME OF POSS',\
       'AVG SEC PER TOUCH', 'AVG DRIB PER TOUCH', 'PTS PER TOUCH',\
       'ELBOW TOUCHES', 'POST UPS', 'PAINT TOUCHES', 'PTS PER ELBOW TOUCH',\
       'PTS PER POST TOUCH', 'PTS PER PAINT TOUCH']
speed_names = ['PLAYER', 'TEAM', 'DIST. FEET', 'DIST. MILES', 'DIST. MILES OFF',\
       'DIST. MILES DEF', 'AVG SPEED', 'AVG SPEED OFF', 'AVG SPEED DEF']

# %%
import pandas as pd
#reading in all the data
stats = pd.read_csv("stats/NBA_stats_BR.csv").drop(["Unnamed: 19", "Unnamed: 24", "Pos", "Age", "Rk",], axis = 1)
stats.Player = stats.Player.replace(regex = r"\\.+",value ="")
stats = stats.set_index(["Player"])
totals = pd.read_csv("stats/NBA_totals_BR.csv").drop(["Rk", "Age", "G", "MP"], axis=1)
totals.Player = totals.Player.replace(regex = r"\\.+",value ="")
totals = totals.set_index(["Player"])
pos = totals.Pos
shooting = pd.read_csv("stats/shooting_zones_NBA.csv", names = shooting_names).drop(["AGE"], axis =1).set_index(["Player"])
passing = pd.read_csv("stats/passing_NBA.csv", names = passing_names).set_index(["Player"])
drives = pd.read_csv("stats/Drives_NBA.csv", names = drives_names).set_index(["PLAYER"])
touches = pd.read_csv("stats/touches_NBA.csv", names = touches_names).set_index(["PLAYER"])
speed = pd.read_csv("stats/speed_NBA.csv", names = speed_names).set_index(["PLAYER"])

#merging everything into 1 table
merged = pd.merge(stats,totals, left_index=True, right_index=True, how = "inner")
merged = pd.merge(merged,shooting, left_index=True, right_index=True, how = "left")
merged = pd.merge(merged,passing, left_index=True, right_index=True, how = "left")
merged = pd.merge(merged,drives, left_index=True, right_index=True, how = "left")
merged = pd.merge(merged,touches, left_index=True, right_index=True, how = "left")
merged = pd.merge(merged,speed, left_index=True, right_index=True, how = "left")

#filtering out players that didn't play much
merged = merged[(merged.G>41)&(merged.MP>1000)]
#dropping irrelevant fields
merged = merged.drop(["GS","Pos", "G", "MP", "TS%", "Tm_y", "Tm_x", "Team_x", "Team_y", "TEAM_x", "TEAM_y", "TEAM"],axis=1)
merged = merged[["3PAr","FTr","ORB%", "DRB%", "AST%","STL%","BLK%", "USG%","OBPM","DBPM", "3P%", "2P%", 'FGA LESS THAN 5FT.','FGA 5-9 FT.', 'FGA 10-14 FT.','FGA 15-19 FT.', 'FGA 20-24 FT.', 'FGA 25-29 FT.', "PASSES MADE", "PASSES RECEIVED", "SECONDARY AST",\
                'AST to PASS% ADJ','DRIVES', 'TOUCHES','FRONT CT TOUCHES', 'AVG SEC PER TOUCH','AVG DRIB PER TOUCH', 'PTS PER TOUCH', 'ELBOW TOUCHES', 'POST UPS',\
       'PAINT TOUCHES','PTS PER ELBOW TOUCH', 'PTS PER POST TOUCH','PTS PER PAINT TOUCH', 'DIST. MILES OFF', 'DIST. MILES DEF','AVG SPEED', 'AVG SPEED OFF', 'AVG SPEED DEF' ]]
#Feature Engineering
merged['POST UP %'] = merged['POST UPS'].astype(float)/merged['TOUCHES'].astype(float)
merged['FRONT CT TOUCH %'] = merged['FRONT CT TOUCHES'].astype(float)/merged['TOUCHES'].astype(float)
merged['PAINT TOUCH %'] = merged['PAINT TOUCHES'].astype(float)/merged['TOUCHES'].astype(float)
merged['ELBOW TOUCH %'] = merged['ELBOW TOUCHES'].astype(float)/merged['TOUCHES'].astype(float)
merged['SPEED DIFF'] = merged['AVG SPEED OFF'].astype(float)-merged['AVG SPEED DEF'].astype(float)
merged['MILES DIFF'] = merged['DIST. MILES OFF'].astype(float)-merged['DIST. MILES DEF'].astype(float)
merged['PASS RATIO'] = merged["PASSES MADE"].astype(float)/merged["PASSES RECEIVED"].astype(float) #pass made / passes received
merged['FGA TOTAL'] = merged['FGA LESS THAN 5FT.'].astype(float)+merged['FGA 5-9 FT.'].astype(float)+merged['FGA 10-14 FT.'].astype(float)+merged['FGA 15-19 FT.'].astype(float)+merged['FGA 20-24 FT.'].astype(float)+merged['FGA 25-29 FT.'].astype(float)
merged['FGA <5 FT. RATIO'] = merged['FGA LESS THAN 5FT.'].astype(float)/merged['FGA TOTAL'].astype(float)
merged['FGA 5-9 FT. RATIO'] = merged['FGA 5-9 FT.'].astype(float)/merged['FGA TOTAL'].astype(float)
merged['FGA 10-14 FT. RATIO'] = merged['FGA 10-14 FT.'].astype(float)/merged['FGA TOTAL'].astype(float)
merged['FGA 15-19 FT. RATIO'] = merged['FGA 15-19 FT.'].astype(float)/merged['FGA TOTAL'].astype(float)
merged['FGA 20-24 FT. RATIO'] = merged['FGA 20-24 FT.'].astype(float)/merged['FGA TOTAL'].astype(float)
merged['FGA 25-29 FT. RATIO'] = merged['FGA 25-29 FT.'].astype(float)/merged['FGA TOTAL'].astype(float)
merged = merged.dropna().drop(['FGA LESS THAN 5FT.','FGA 5-9 FT.','FGA 10-14 FT.', 'FGA 15-19 FT.', 'FGA 20-24 FT.', 'FGA 25-29 FT.', "SECONDARY AST", "PASSES MADE", "PASSES RECEIVED", 'TOUCHES','FRONT CT TOUCHES', 'PAINT TOUCHES', 'ELBOW TOUCHES',"POST UPS", 'AVG SPEED DEF', 'AVG SPEED OFF', 'DIST. MILES OFF', 'DIST. MILES DEF'], axis =1)
merged.shape
merged.columns
# Out:
# Index(['3PAr', 'FTr', 'ORB%', 'DRB%', 'AST%', 'STL%', 'BLK%', 'USG%', 'OBPM',
#        'DBPM', '3P%', '2P%', 'AST to PASS% ADJ', 'DRIVES', 'AVG SEC PER TOUCH',
#        'AVG DRIB PER TOUCH', 'PTS PER TOUCH', 'PTS PER ELBOW TOUCH',
#        'PTS PER POST TOUCH', 'PTS PER PAINT TOUCH', 'AVG SPEED', 'POST UP %',
#        'FRONT CT TOUCH %', 'PAINT TOUCH %', 'ELBOW TOUCH %', 'SPEED DIFF',
#        'MILES DIFF', 'PASS RATIO', 'FGA TOTAL', 'FGA <5 FT. RATIO',
#        'FGA 5-9 FT. RATIO', 'FGA 10-14 FT. RATIO', 'FGA 15-19 FT. RATIO',
#        'FGA 20-24 FT. RATIO', 'FGA 25-29 FT. RATIO'],
#       dtype='object')

# %%
#normalize the dataset
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
Data = scaler.fit_transform(merged)
norm_stats = pd.DataFrame(Data, index = merged.index, columns = merged.columns)

# %% [markdown]
# ## Principal Components Analysis:

# %%
#Using PCA to identify components
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
pca = PCA(n_components=14)
pca.fit(norm_stats)
print(pca.explained_variance_ratio_)
print("Percent of variance explained by all components:", sum(pca.explained_variance_ratio_))
plt.bar(range(len(pca.explained_variance_ratio_)), pca.explained_variance_ratio_)
results = pd.DataFrame(index = norm_stats.index)
PC = pd.DataFrame()
for i, component in enumerate(pca.components_):
    top_idx = np.argsort(np.absolute(component))[-5:]
    cols = np.flip(np.array(norm_stats.columns).take(top_idx),axis=0)
    x = np.flip(component.take(top_idx), axis=0)
    PC["PC"+str(i)] = cols+x.astype(str)
    results["PC"+str(i)]=np.dot(norm_stats, component)
# Out:
# [ 0.31705619  0.18955183  0.12238038  0.0513107   0.04753285  0.04324346
#   0.02868387  0.02264327  0.02034681  0.01889988  0.01621042  0.01383423
#   0.01301383  0.0119244 ]
# Percent of variance explained by all components: 0.916632112478

# %%
#Recording the top and bottom players for each component
def top(x, k=30):
    return x.sort_values()[-k:].index
def bottom(x, k=10):
    return x.sort_values()[:k].index
def common(x):
    #print(pos[x].value_counts())
    #PC_Pos[] = pos[x].value_counts()[:3].index
    return (pos[x].value_counts()[:2].index)+"-("+pos[x].value_counts()[:2].astype(str)+")"
top10 = results.apply(top)
bot10 = results.apply(bottom)
print("Breaking down each PC by top 2 positions")
print(top10.apply(common))
#Number of players in each position
print("No. of players per position in my dataset:")
print(pos.value_counts())
# Out:
# Breaking down each PC by top 2 positions
#        PC0     PC1      PC2      PC3     PC4     PC5     PC6      PC7     PC8  \
# 0  PG-(23)  C-(17)  SG-(18)  PF-(16)  PG-(8)  C-(12)  SF-(8)  SG-(11)  C-(11)
# 1   SG-(7)  PG-(5)   PF-(5)   PG-(7)  SG-(6)  PF-(8)  PG-(7)    C-(8)  PG-(7)
#
#       PC9    PC10    PC11     PC12     PC13
# 0  PF-(9)  SG-(8)  C-(11)  SG-(13)  SG-(10)
# 1  PG-(8)  PF-(7)  SG-(9)   PG-(9)   PG-(7)
# No. of players per position in my dataset:
# SG       128
# PG       111
# PF       105
# C        105
# SF        88
# SF-SG      2
# PG-SG      1
# Name: Pos, dtype: int64

# %%
print("Top attributes in each principal component")
PC
# Out:
# Top attributes in each principal component
#                                      PC0  \
# 0  AVG DRIB PER TOUCH0.38781479527497836
# 1    AVG SEC PER TOUCH0.3490609337084594
# 2               DRIVES0.2731599067911195
# 3                ORB%-0.2481850224619635
# 4     AST to PASS% ADJ0.2475790740411754
#
#                                     PC1                                  PC2  \
# 0        FGA 5-9 FT.0.35694388433000923     PTS PER TOUCH0.45504170434768726
# 1               3PAr-0.3530570774113765  FRONT CT TOUCH %0.36808565819021355
# 2  FGA LESS THAN 5FT.0.3328648117795188      FGA 20-24 FT.0.3251953336685866
# 3               USG%0.27753321987583235      FGA 25-29 FT.0.2680838745887534
# 4                FTr0.22316754924759719     FGA 15-19 FT.0.22401456048037277
#
#                                    PC3                               PC4  \
# 0         SPEED DIFF0.4096055683631889           STL%0.33435679801293716
# 1         MILES DIFF0.3599685026641406            OBPM0.3246008631019084
# 2  FRONT CT TOUCH %-0.3004118571400662    FGA 5-9 FT.-0.2960954756682864
# 3         PASS RATIO0.2910569172793884             2P%0.2797696991022594
# 4      FGA 25-29 FT.0.2829272220553288  FGA 10-14 FT.-0.2773091003975542
#
#                                        PC5                              PC6  \
# 0             AVG SPEED-0.4297875867079127           STL%0.5891602230796089
# 1           SPEED DIFF-0.42736226334289573          DBPM0.41401654967775864
# 2  PTS PER ELBOW TOUCH-0.40581923073402804  FGA 15-19 FT.0.2493825014122821
# 3                   2P%-0.3470359718516371     AVG SPEED0.23240421868982647
# 4   PTS PER PAINT TOUCH-0.2618646549341779  FGA 20-24 FT.0.2025620912818027
#
#                                       PC7  \
# 0  PTS PER ELBOW TOUCH-0.5099148539802227
# 1      FRONT CT TOUCH %0.4556991335655571
# 2            AVG SPEED0.30579777229893534
# 3      AST to PASS% ADJ0.3049618730247354
# 4            SPEED DIFF0.2911715907330457
#
#                                      PC8  \
# 0         FGA 5-9 FT.-0.5732507189783487
# 1        FGA 15-19 FT.0.4760197124042166
# 2                 BLK%0.3238119666937125
# 3                 FTr0.25274585373529224
# 4  FGA LESS THAN 5FT.-0.2287802488879158
#
#                                       PC9  \
# 0                  FTr-0.4931603001447824
# 1                  2P%0.39949513535732206
# 2                 AST%0.29897032714541893
# 3      AST to PASS% ADJ0.2755937360980514
# 4  FGA LESS THAN 5FT.-0.23575837218678036
#
#                                      PC10  \
# 0                   FTr0.3558230042011117
# 1                 2P%-0.30227506227127704
# 2                  BLK%0.2981816786828183
# 3  PTS PER ELBOW TOUCH0.28815111422192796
# 4                 OBPM-0.2649740138204745
#
#                                      PC11  \
# 0                 DRB%0.33849406909019375
# 1   PTS PER ELBOW TOUCH0.3298555027065778
# 2                 ORB%0.29218200604284433
# 3  PTS PER PAINT TOUCH-0.2829830095645839
# 4        FGA 20-24 FT.0.26477357050115946
#
#                                      PC12  \
# 0    PTS PER POST TOUCH0.8052680161534445
# 1                  BLK%0.2892758732104162
# 2  PTS PER PAINT TOUCH-0.2260225737546011
# 3        FGA 15-19 FT.-0.1978945428700719
# 4  PTS PER ELBOW TOUCH0.19297777308234842
#
#                                      PC13
# 0           MILES DIFF-0.4008514225314004
# 1                BLK%-0.39343073475790424
# 2                  DRB%0.3436410883919602
# 3  PTS PER PAINT TOUCH0.26026534432253395
# 4                  USG%0.2566880206279824

# %% [markdown]
# ## Clustering based on reduced dimensions: (KMeans)

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, silhouette_samples
import matplotlib.cm as cm
import numpy as np
range_n_clusters = range(2, 16)
labels = {}
for n_clusters in range_n_clusters:
    fig, (ax1) = plt.subplots(1)
    fig.set_size_inches(10, 5)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(results) + (n_clusters + 1) * 10])
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(results)
    labels[n_clusters] = cluster_labels
    silhouette_avg = silhouette_score(results, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)
    sample_silhouette_values = silhouette_samples(results, cluster_labels)
    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.220956714823
# For n_clusters = 3 The average silhouette_score is : 0.226434511838
# For n_clusters = 4 The average silhouette_score is : 0.20735928694
# For n_clusters = 5 The average silhouette_score is : 0.16858695568
# For n_clusters = 6 The average silhouette_score is : 0.173616960307
# For n_clusters = 7 The average silhouette_score is : 0.160590408061
# For n_clusters = 8 The average silhouette_score is : 0.139783146519
# For n_clusters = 9 The average silhouette_score is : 0.143041461914
# For n_clusters = 10 The average silhouette_score is : 0.133644743398
# For n_clusters = 11 The average silhouette_score is : 0.126628435089
# For n_clusters = 12 The average silhouette_score is : 0.137321945485
# For n_clusters = 13 The average silhouette_score is : 0.130103294561
# For n_clusters = 14 The average silhouette_score is : 0.116233181604
# For n_clusters = 15 The average silhouette_score is : 0.11450461916

# %%
#Based on the sillhouette plots and sillhouette scores, 8 or 12 clusters seem to be the best fits for the Data
groups = pd.DataFrame(labels[6], index = results.index).groupby(0)
print(groups.groups)
# for name, group in groups:
#     print(group.join)
# 2 Most common positions in each group
# Out:
# {0: Index(['Aaron Gordon', 'Alec Burks', 'Allen Crabbe', 'Andrew Wiggins',
#        'Avery Bradley', 'Bogdan Bogdanovic', 'Bojan Bogdanovic', 'Bryn Forbes',
#        'Buddy Hield', 'Carmelo Anthony', 'Courtney Lee', 'Darius Miller',
#        'DeMarre Carroll', 'Denzel Valentine', 'Dillon Brooks', 'E'Twaun Moore',
#        'Eric Gordon', 'Evan Fournier', 'Garrett Temple', 'Gary Harris',
#        'Ian Clark', 'Jamal Crawford', 'Jaylen Brown', 'Jayson Tatum',
#        'Jeremy Lamb', 'Jodie Meeks', 'Joe Harris', 'Joe Ingles',
#        'Jonathon Simmons', 'Josh Jackson', 'Justin Holiday', 'Kent Bazemore',
#        'Kentavious Caldwell-Pope', 'Klay Thompson', 'Kyle Korver',
#        'Kyle Kuzma', 'Luke Kennard', 'Manu Ginobili', 'Marco Belinelli',
#        'Marco Belinelli', 'Marcus Morris', 'Nick Young', 'Nicolas Batum',
#        'Norman Powell', 'Reggie Bullock', 'Rodney Hood', 'Stanley Johnson',
#        'Tobias Harris', 'Tobias Harris', 'Trevor Ariza', 'Troy Daniels',
#        'Tyler Johnson', 'Wayne Ellington', 'Wesley Matthews'],
#       dtype='object'), 1: Index(['Ben Simmons', 'Bradley Beal', 'Brandon Ingram', 'CJ McCollum',
#        'Chris Paul', 'D'Angelo Russell', 'Damian Lillard', 'DeMar DeRozan',
#        'Dennis Schroder', 'Devin Booker', 'Donovan Mitchell', 'Eric Bledsoe',
#        'Eric Bledsoe', 'Goran Dragic', 'Jamal Murray', 'James Harden',
#        'Jimmy Butler', 'Jordan Clarkson', 'Jordan Clarkson', 'Jrue Holiday',
#        'Kemba Walker', 'Kevin Durant', 'Khris Middleton', 'Kris Dunn',
#        'Kyrie Irving', 'LeBron James', 'Lou Williams', 'Paul George',
#        'Reggie Jackson', 'Russell Westbrook', 'Stephen Curry', 'Tyreke Evans',
#        'Victor Oladipo', 'Will Barton'],
#       dtype='object'), 2: Index(['Alex Len', 'Amir Johnson', 'Andre Drummond', 'Aron Baynes',
#        'Bam Adebayo', 'Bismack Biyombo', 'Clint Capela', 'Derrick Favors',
#        'Domantas Sabonis', 'Dwight Howard', 'Dwight Powell', 'Ed Davis',
#        'Enes Kanter', 'Hassan Whiteside', 'Ian Mahinmi', 'Jakob Poeltl',
#        'Jarrett Allen', 'Jerami Grant', 'John Collins', 'John Henson',
#        'Jonas Valanciunas', 'Julius Randle', 'Jusuf Nurkic', 'Kyle O'Quinn',
#        'Mason Plumlee', 'Montrezl Harrell', 'Myles Turner', 'Pau Gasol',
#        'Skal Labissiere', 'Steven Adams', 'Taj Gibson', 'Trevor Booker',
#        'Tyler Zeller', 'Willie Cauley-Stein'],
#       dtype='object'), 3: Index(['Al-Farouq Aminu', 'Alex Abrines', 'Andre Iguodala', 'Anthony Tolliver',
#        'Ben McLemore', 'Corey Brewer', 'Danny Green', 'Dante Cunningham',
#        'Dante Cunningham', 'Dario Saric', 'David Nwaba', 'Davis Bertans',
#        'Dewayne Dedmon', 'Dirk Nowitzki', 'Doug McDermott', 'Doug McDermott',
#        'Dragan Bender', 'Draymond Green', 'Ersan Ilyasova', 'Ersan Ilyasova',
#        'Frank Kaminsky', 'Gorgui Dieng', 'JaMychal Green', 'Jae Crowder',
#        'Jae Crowder', 'James Johnson', 'Jarell Martin', 'Jeff Green',
#        'Joe Johnson', 'Jonas Jerebko', 'Josh Hart', 'Justin Jackson',
#        'Justise Winslow', 'Kelly Olynyk', 'Kyle Anderson', 'Lance Thomas',
#        'Lauri Markkanen', 'Luc Mbah a Moute', 'Mario Hezonja',
#        'Marquese Chriss', 'Marvin Williams', 'Maurice Harkless', 'Maxi Kleber',
#        'Michael Kidd-Gilchrist', 'Mike Muscala', 'Mike Scott',
#        'Nemanja Bjelica', 'Nikola Mirotic', 'OG Anunoby', 'Pascal Siakam',
#        'Pat Connaughton', 'Patrick Patterson', 'Quincy Acy',
#        'Robert Covington', 'Royce O'Neale', 'Ryan Anderson', 'Semi Ojeleye',
#        'Serge Ibaka', 'Sindarius Thornwell', 'Thaddeus Young', 'Thon Maker',
#        'Tony Snell', 'Treveon Graham', 'Trey Lyles', 'Vince Carter',
#        'Wesley Johnson', 'Wilson Chandler', 'Zach Collins'],
#       dtype='object'), 4: Index(['Andrew Harrison', 'Austin Rivers', 'Caris LeVert', 'Cory Joseph',
#        'D.J. Augustin', 'Darren Collison', 'De'Aaron Fox', 'Dejounte Murray',
#        'Delon Wright', 'Devin Harris', 'Dwyane Wade', 'Dwyane Wade',
#        'Elfrid Payton', 'Elfrid Payton', 'Emmanuel Mudiay', 'Evan Turner',
#        'Frank Ntilikina', 'Fred VanVleet', 'George Hill', 'George Hill',
#        'Isaiah Taylor', 'Ish Smith', 'J.J. Barea', 'Jameer Nelson',
#        'Jarrett Jack', 'Jeff Teague', 'Jerian Grant', 'Josh Richardson',
#        'Kyle Lowry', 'Lance Stephenson', 'Lonzo Ball', 'Malcolm Brogdon',
#        'Malcolm Delaney', 'Marcus Smart', 'Mario Chalmers', 'Milos Teodosic',
#        'Patty Mills', 'Rajon Rondo', 'Raymond Felton', 'Ricky Rubio',
#        'Shabazz Napier', 'Shaun Livingston', 'Shelvin Mack',
#        'Spencer Dinwiddie', 'T.J. McConnell', 'Terry Rozier',
#        'Tomas Satoransky', 'Tony Parker', 'Tyler Ulis', 'Tyus Jones',
#        'Yogi Ferrell'],
#       dtype='object'), 5: Index(['Al Horford', 'Anthony Davis', 'Blake Griffin', 'Bobby Portis',
#        'Brook Lopez', 'DeMarcus Cousins', 'Giannis Antetokounmpo',
#        'Harrison Barnes', 'Joel Embiid', 'Karl-Anthony Towns', 'Kevin Love',
#        'Kristaps Porzingis', 'LaMarcus Aldridge', 'Marc Gasol',
#        'Markieff Morris', 'Michael Beasley', 'Nikola Jokic', 'Nikola Vucevic',
#        'Robin Lopez', 'Rondae Hollis-Jefferson', 'Rudy Gay', 'Zach Randolph'],
#       dtype='object')}

# %%
#most common position in each cluster:
for group in groups.groups:
    #print(groups.groups[group])
    print(group)
    print(pos[groups.groups[group]].value_counts())
    print(results.loc[groups.groups[group]].sum())
# Out:
# 0
# SG    34
# SF    13
# PF     6
# PG     1
# Name: Pos, dtype: int64
# PC0     29.077040
# PC1     30.752524
# PC2     71.781934
# PC3     12.546163
# PC4     27.769335
# PC5    -49.654829
# PC6     33.402319
# PC7     27.539162
# PC8     -0.044881
# PC9      5.908329
# PC10     7.492849
# PC11     7.846607
# PC12     9.908004
# PC13    -3.288749
# dtype: float64
# 1
# PG    16
# SG    13
# SF     3
# PF     2
# Name: Pos, dtype: int64
# PC0     45.235262
# PC1     50.635519
# PC2     38.348735
# PC3     12.577746
# PC4     22.709534
# PC5    -33.994584
# PC6     21.002240
# PC7     15.764612
# PC8      2.485033
# PC9      4.243638
# PC10     2.191441
# PC11     3.201346
# PC12     4.940184
# PC13    -2.555075
# dtype: float64
# 2
# C     29
# PF     5
# Name: Pos, dtype: int64
# PC0    -22.565381
# PC1     44.647789
# PC2     21.294065
# PC3      8.995888
# PC4     18.382557
# PC5    -30.469566
# PC6     15.699403
# PC7     14.499751
# PC8      2.823504
# PC9      3.121149
# PC10     3.389798
# PC11     5.653347
# PC12     5.975880
# PC13    -3.051528
# dtype: float64
# 3
# PF       33
# SF       19
# SG        9
# C         6
# SF-SG     1
# Name: Pos, dtype: int64
# PC0      0.181917
# PC1     35.349899
# PC2     60.894046
# PC3     29.530314
# PC4     39.720371
# PC5    -62.972671
# PC6     44.945406
# PC7     29.705550
# PC8     -0.614121
# PC9      9.813438
# PC10     7.248280
# PC11     6.327290
# PC12    10.023834
# PC13    -3.981830
# dtype: float64
# 4
# PG    41
# SG     7
# SF     3
# Name: Pos, dtype: int64
# PC0     54.619099
# PC1     49.852892
# PC2     23.679335
# PC3     14.412402
# PC4     24.281046
# PC5    -44.438899
# PC6     30.334593
# PC7     21.416168
# PC8      1.636004
# PC9      8.096539
# PC10     6.657778
# PC11     5.301445
# PC12     9.898088
# PC13    -3.279209
# dtype: float64
# 5
# C     11
# PF    10
# SF     1
# Name: Pos, dtype: int64
# PC0     -0.821729
# PC1     32.051367
# PC2     27.121513
# PC3      8.698759
# PC4      8.339622
# PC5    -12.754141
# PC6     11.792198
# PC7      9.668033
# PC8     -1.878524
# PC9      4.149550
# PC10     2.739169
# PC11     0.808703
# PC12     2.771405
# PC13    -0.699976
# dtype: float64
